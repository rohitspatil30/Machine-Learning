# %% [markdown]
# # plotting from pandas Dataframes
# The actual data is not plotted directly using the numpy array but using the dataframes or tables , it is tables which is converted to the visual representation for better understanding.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
print("Imported!")
# Out:
# Imported!

# %%
file = pd.read_csv("../pandas/class-grades.csv")
print(file)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15    NaN
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70    NaN
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
file = file.fillna(file.mean())
file #filled the missing values using the mean of each column
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome      Final
# 0        5       57.14     34.09    64.38     51.48  52.500000
# 1        8       95.05    105.49    67.50     99.07  68.330000
# 2        8       83.70     83.17    30.00     63.15  69.244409
# 3        7       81.22     96.06    49.38    105.93  80.560000
# 4        8       91.32     93.64    95.00    107.41  73.890000
# ..     ...         ...       ...      ...       ...        ...
# 94       8       96.73    103.71    45.00     93.52  61.940000
# 95       7       85.34     80.54    41.25     93.70  69.244409
# 96       8       89.94    102.77    87.50     90.74  87.780000
# 97       7       95.60     76.13    66.25     99.81  85.560000
# 98       8       63.40     97.37    73.12     72.78  77.220000
#
# [99 rows x 6 columns]

# %%
#plotting the graph
file.hist("Tutorial"); 
#directly specify the columns name in the hist value as the function takes the series or list as input and every column is
# list in itself.

# %%
file["Roll no"]=[num for num in range(1,len(file["Final"])+1)]
file.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm    TakeHome      Final  Roll no
# 0       5       57.14     34.09    64.38   51.480000  52.500000        1
# 1       8       95.05    105.49    67.50   99.070000  68.330000        2
# 2       8       83.70     83.17    30.00   63.150000  69.244409        3
# 3       7       81.22     96.06    49.38  105.930000  80.560000        4
# 4       8       91.32     93.64    95.00  107.410000  73.890000        5
# 5       7       95.00     92.58    93.12   97.780000  68.060000        6
# 6       8       95.05    102.99    56.25   99.070000  50.000000        7
# 7       7       72.85     86.85    60.00   80.672784  56.110000        8
# 8       8       84.26     93.10    47.50   18.520000  50.830000        9
# 9       7       90.10     97.55    51.25   88.890000  63.610000       10

# %%
file.plot("Roll no","Final",title="Final marks", xlabel = "roll no.", ylabel="Marks obtained");

# %%
file.plot("Roll no","Final",title="Final marks", xlabel = "roll no.", ylabel="Marks obtained",kind="bar");

# %%
file.plot("Roll no","Final",title="Final marks", xlabel = "roll no.", ylabel="Marks obtained",kind="scatter");

# %%
file.hist("Final");

# %%
df = pd.DataFrame(np.random.randint(1,100,size=(10,4)),columns=["a","b","c","d"]) #another method to create a dataframe.
# create values using the random matrix function, and give name to each column
df
# Out:
#     a   b   c   d
# 0   3  30  66  69
# 1  63  50  87   1
# 2  57  77  23  46
# 3  38  23  27  89
# 4  68  47  68  57
# 5  92  61  10   4
# 6  78  80  82  85
# 7  96  50  39  11
# 8  96  58  25  64
# 9   4  36   7  49

# %%
df.plot.bar();

# %%
#plotting histogram
file["Assignment"].plot(kind="hist",title="Histogram");

# %%
figure, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,10));
ax1.scatter(file["Roll no"],file["Assignment"]);
ax1.set(title="Assignment marks",xlabel="Roll numbers",ylabel="Assignment marks")
ax2.bar(file["Roll no"],file["Tutorial"]);
ax2.set(title="Tutorial marks",xlabel="Roll numbers",ylabel="Tutorial marks");
ax3.bar(file["Roll no"],file["Final"]);
ax3.set(title="Final marks",xlabel="Roll numbers",ylabel="Final marks");
ax4.bar(file["Roll no"],file["Midterm"]);
ax4.set(title="Midterm marks",xlabel="Roll numbers",ylabel="Midterm");

# %%
#another method to print the histograms of the file
file.plot.hist(figsize=(10,12),subplots =True);

# %% [markdown]
# This does not look like ideal data visualisation.
#
# ![image.png](attachment:56f07d28-420c-43ef-84e7-4a9d609cce8c.png)

# %%
#pyplot method to produce a quick graph
over_50_marks = file[file["Final"]>=50]
over_50_marks.plot(kind="bar",x="Roll no",y="Final",title="Final marks");

# %%
over_50_marks.plot(kind="scatter",x="Roll no",y="Final",title="Final marks",c="Final");

# %%
#oo method
# two methods by calling the pylot dataframe to plot the table and the second method is to call the axis to make x and y of the file series.
fig,ax = plt.subplots(figsize=(10,10));
# call the dataframe
over_50_marks.plot(kind="scatter",
         x="Roll no",
         y="Tutorial",
         c="Tutorial",
            ax=ax);

# %%
fig,ax = plt.subplots(figsize=(10,10));
ax.scatter(x=over_50_marks["Roll no"],y=over_50_marks["Final"],c=over_50_marks["Final"]);
ax.set(title="Scatter plot using oo method");
ax.axhline(over_50_marks["Final"].mean(), ls="--");

# %% [markdown]
# # Shared values on same x or y axis on a subplot

# %%
fig, ((ax1),(ax2),(ax3),(ax4)) = plt.subplots(nrows=4,ncols=1,figsize=(10,30),sharex=True)

# graph ax1
scatter = ax1.scatter(x=over_50_marks["Roll no"],y=over_50_marks["Tutorial"],c=over_50_marks["Tutorial"]);
ax1.legend(*scatter.legend_elements(), title="Legends")
ax1.set(ylabel="Tutorial",title="Tutorial graph");
ax1.axhline(over_50_marks["Tutorial"].mean(),ls="--");
ax1.set_xlim([1,85]);
ax1.set_ylim([50,100])

# graph ax2
ax1.scatter(x=over_50_marks["Roll no"],y=over_50_marks["Assignment"],c=over_50_marks["Assignment"]);
ax1.set(ylabel="Assignment",title="Assignment graph");
ax1.axhline(over_50_marks["Assignment"].mean());

# graph ax3
ax2.scatter(x=over_50_marks["Roll no"],y=over_50_marks["Assignment"],c=over_50_marks["Assignment"]);
ax2.set(ylabel="Assignment",title="Assignment graph");
ax2.axhline(over_50_marks["Assignment"].mean(),ls="--");


# graph ax4
ax3.scatter(x=over_50_marks["Roll no"],y=over_50_marks["Midterm"]);
ax3.set(xlabel="Roll no",ylabel="Midterm",title="Midterm graph");
ax3.axhline(over_50_marks["Midterm"].mean(),ls="--");

# graph ax5
ax4.scatter(x=over_50_marks["Roll no"],y=over_50_marks["Final"]);
ax4.set(xlabel="Roll no",ylabel="Final",title="Final graph");
ax4.axhline(over_50_marks["Final"].mean(),ls="--");

fig.suptitle("Class Grades\nThe Final Grades for the annual year",fontweight="bold",fontsize="24");

#adding grid to the plots
plt.style.available;

# %%
plt.style.use('seaborn');
ax = over_50_marks.plot(subplots=True,figsize=(10,30));
plt.legend().set_visible(True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21204\4165184347.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn');

# %%
plt.bar([num for num in range(1,101)],np.random.randint(300,450,size=(100)));

# %%
df = pd.DataFrame(np.random.randint(1,30,size=(4,4)),columns=["a","b","c","d"]);
df.plot(kind="bar")
plt.legend().set_visible(True)

# %%
fig.savefig("../graphs_and_images/Class-grades.png")
print("saved")
# Out:
# saved
